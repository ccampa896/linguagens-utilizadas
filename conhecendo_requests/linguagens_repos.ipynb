# %%
# Importando a biblioteca Requests
import requests

# %%
# Solicitação GET no endpoint da API referenciada no endereço
r = requests.get('https://api.github.com/events')

# %%
# Objeto do tipo Response
r
# Out:
# <Response [200]>

# %% [markdown]
# # Explorando a biblioteca

# %%
# Retornando o Status da solicitação
r.status_code
# Out:
# 200

# %%
# URL utilizada no endpoint
r.url
# Out:
# 'https://api.github.com/events'

# %%
# Conteúdo do Objeto Response 'r' em formato de string
r.text
# Out:
# '[{"id":"31810811935","type":"PushEvent","actor":{"id":144823004,"login":"masilova23","display_login":"masilova23","gravatar_id":"","url":"https://api.github.com/users/masilova23","avatar_url":"https://avatars.githubusercontent.com/u/144823004?"},"repo":{"id":691166835,"name":"masilova23/masilova23.github.io","url":"https://api.github.com/repos/masilova23/masilova23.github.io"},"payload":{"repository_id":691166835,"push_id":15030375101,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"85bd40265f8f169b7a11dcb03e186e8acf86df80","before":"ac9c171c966c401c483171e4e92143f2827d7258","commits":[{"sha":"85bd40265f8f169b7a11dcb03e186e8acf86df80","author":{"email":"144823004+masilova23@users.noreply.github.com","name":"masilova23"},"message":"Update and rename ЗАДАНИЕ.html to index.html","distinct":true,"url":"https://api.github.com/repos/masilova23/masilova23.github.io/commits/85bd40265f8f169b7a11dcb03e186e8acf86df80"}]},"public":true,"created_at":"2023-09-13T16:41:44Z"},{"id":"31810
# ...

# %%
# Em formato de JSON
r.json()
# Out:
# [{'id': '31810811935',
#   'type': 'PushEvent',
#   'actor': {'id': 144823004,
#    'login': 'masilova23',
#    'display_login': 'masilova23',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/masilova23',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/144823004?'},
#   'repo': {'id': 691166835,
#    'name': 'masilova23/masilova23.github.io',
#    'url': 'https://api.github.com/repos/masilova23/masilova23.github.io'},
#   'payload': {'repository_id': 691166835,
#    'push_id': 15030375101,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '85bd40265f8f169b7a11dcb03e186e8acf86df80',
#    'before': 'ac9c171c966c401c483171e4e92143f2827d7258',
#    'commits': [{'sha': '85bd40265f8f169b7a11dcb03e186e8acf86df80',
#      'author': {'email': '144823004+masilova23@users.noreply.github.com',
#       'name': 'masilova23'},
#      'message': 'Update and rename ЗАДАНИЕ.html to index.html',
#      'distinct': True,
# ...

# %% [markdown]
# # Utilizando outro endpoint

# %%
r = requests.get('http://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']
